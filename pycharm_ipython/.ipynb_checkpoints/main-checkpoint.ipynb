# %%
# ecoding = gbk

# %%
import pandas
from pandas import DataFrame
from pandas import Series

# %%
# %run D:\python\cross_signal\main.py
# Out:
#            s_info_windcode  s_dq_close  s_dq_pctchange        ma_5  \
# trade_dt
# 2005-01-31       000905.SH    922.6530         -3.1247   966.78940
# 2005-02-01       000905.SH    913.3310         -1.0103   949.54500
# 2005-02-02       000905.SH    964.2430          5.5743   944.80260
# 2005-02-03       000905.SH    945.3120         -1.9633   939.59040
# 2005-02-04       000905.SH    962.0280          1.7683   941.51340
# 2005-02-16       000905.SH    972.3370          1.0716   951.45020
# 2005-02-17       000905.SH    977.2720          0.5075   964.23840
# 2005-02-18       000905.SH    964.7690         -1.2794   964.34360
# 2005-02-21       000905.SH    981.8190          1.7673   971.64500
# 2005-02-22       000905.SH   1007.6880          2.6348   980.77700
# 2005-02-23       000905.SH   1019.2580          1.1482   990.16120
# 2005-02-24       000905.SH   1024.4460          0.5090   999.59600
# 2005-02-25       000905.SH   1024.1180         -0.0320  1011.46580
# ...

# %% [markdown]
# what

# %%
cd
# Out:
# C:\Users\ThinkStation
